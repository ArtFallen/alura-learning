# %% [markdown]
# # **Desafío: ¡Es hora de practicar!**
#
# Vamos practicar el uso de estructuras de repetición como el "while" y el "for" a partir de algunas actividades. Ahora que estamos avanzando en el contenido, podemos hacer los desafíos más interesantes. ¡Para ello, trabajaremos en proyectos de código!
#
# Comencemos resolviendo algunos problemas para calentar y prepararnos para los proyectos.
#
# ---

# %% [markdown]
# ### **Entrenando la programación**

# %% [markdown]
# 1 - Escribe un programa que solicite dos números enteros e imprima todos los números enteros entre ellos.

# %%
"""1 - Escribe un programa que solicite dos números enteros e imprima todos los números enteros entre ellos."""
num1 = int(input("Ingrese el primer número entero: "))
num2 = int(input("Ingrese el segundo número entero: "))
if num1 < num2:
    for i in range(num1 + 1, num2):765
        print("Número entero entre {} y {}: {}".format(num1, num2, i))
elif num1 > num2:
    for i in range(num2 + 1, num1):
        print("Número entero entre {} y {}: {}".format(num2, num1, i))
else:
      print("Los números son iguales. No hay números enteros entre ellos.")

# %% [markdown]
# 2 - Escribe un programa para calcular cuántos días tomará que la colonia de una bacteria A supere o iguale a la colonia de una bacteria B, basado en tasas de crecimiento del 3% y 1.5%, respectivamente. Supón que la colonia A comienza con 4 elementos y B con 10.

# %%
colonia_a = 4
colonia_b = 10
tasa_a = 0.03
tasa_b = 0.015
dias = 0
while colonia_a < colonia_b:
    colonia_a += colonia_a * tasa_a
    colonia_b += colonia_b * tasa_b
    dias += 1
print("La colonia A superará o igualará a la colonia B en {} días.".format(dias))
# Out:
# La colonia A superará o igualará a la colonia B en 63 días.

# %% [markdown]
# 3 - Para procesar una cantidad de 15 datos de evaluaciones de usuarios de un servicio de la empresa, necesitamos verificar si las calificaciones son válidas. Por lo tanto, escribe un programa que recibirá calificaciones del 0 al 5 y verificará si son valores válidos. Si se ingresa una calificación superior a 5 o inferior a 0, se repetirá hasta que el usuario ingrese un valor válido.

# %%
for i in range(15):
    while True:
        calificacion = float(input("Ingrese una calificación entre 0 y 5: "))
        if 0 <= calificacion <= 5:
            print("Calificación válida: {}".format(calificacion))
            break
        else:
            print("Calificación inválida. Por favor, ingrese un valor entre 0 y 5.")
# Out:
# Calificación válida: 3.0
# Calificación válida: 2.0
# Calificación válida: 4.0
# Calificación válida: 3.0
# Calificación válida: 2.0
# Calificación válida: 3.0
# Calificación válida: 4.0
# Calificación válida: 5.0
# Calificación válida: 4.0
# Calificación válida: 3.0
# Calificación válida: 4.0
# Calificación válida: 5.0
# Calificación válida: 4.0
# Calificación válida: 3.0
# Calificación válida: 4.0

# %% [markdown]
# 4 - Desarrolla un programa que lea un conjunto indefinido de temperaturas en grados Celsius y calcule su promedio. La lectura debe detenerse al ingresar el valor -273°C.

# %%
"""4 - Desarrolla un programa que lea un conjunto indefinido de temperaturas en grados Celsius y calcule su promedio. La lectura debe detenerse al ingresar el valor -273°C."""
temperaturas = []
while True:
    temp = float(input("Ingrese una temperatura en grados Celsius (o -273 para finalizar): "))
    if temp == -273:
        break
    temperaturas.append(temp)
if temperaturas:
    promedio = sum(temperaturas) / len(temperaturas)
    print("El promedio de las temperaturas ingresadas es: {:.2f}°C".format(promedio))
# Out:
# El promedio de las temperaturas ingresadas es: 126.94°C

# %% [markdown]
# 5 - Escribe un programa que calcule el factorial de un número entero proporcionado por el usuario. Recuerda que el factorial de un número entero es el producto de ese número por todos sus antecesores hasta llegar al número 1. Por ejemplo, el factorial de 5 es 5 x 4 x 3 x 2 x 1 = 120.

# %%
"""5 - Escribe un programa que calcule el factorial de un número entero proporcionado por el usuario. Recuerda que el factorial de un número entero es el producto de ese número por todos sus antecesores hasta llegar al número 1. Por ejemplo, el factorial de 5 es 5 x 4 x 3 x 2 x 1 = 120."""
num = int(input("Ingrese un número entero para calcular su factorial: "))
if num < 0:
    print("El factorial no está definido para números negativos.")
elif num == 0 or num == 1:
    print("El factorial de {} es 1.".format(num))
else:
    factorial = 1
    for i in range(2, num + 1):
        factorial *= i
    print("El factorial de {} es {}.".format(num, factorial))
# Out:
# El factorial de 23 es 25852016738884976640000.

# %% [markdown]
# ### **Momento de los proyectos**

# %% [markdown]
# 6 - Escribe un programa que genere la tabla de multiplicar de un número entero del 1 al 10, según la elección del usuario. Como ejemplo, para el número 2, la tabla de multiplicar debe mostrarse en el siguiente formato:
# ```
# Tabla de multiplicar del 2:
# 2 x 1 = 2
# 2 x 2 = 4
# [...]
# 2 x 10 = 20
# ```

# %%
num = int(input("Ingrese un número entero para generar su tabla de multiplicar: "))
print("Tabla de multiplicar del {}:".format(num))
for i in range(1, 11):
    print("{} x {} = {}".format(num, i, num * i))
# Out:
# Tabla de multiplicar del 12:
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120

# %% [markdown]
# 7 - Los números primos tienen diversas aplicaciones en Ciencia de Datos, como en criptografía y seguridad. Un número primo es aquel que es divisible solo por sí mismo y por 1. Por lo tanto, crea un programa que solicite un número entero y determine si es un número primo o no.

# %%
num = int(input("Ingrese un número entero para verificar si es primo: "))
if num <= 1:
    print("{} no es un número primo.".format(num))
else:
    es_primo = True
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            es_primo = False
            break
    if es_primo:
        print("{} es un número primo.".format(num))
    else:
        print("{} no es un número primo.".format(num))
# Out:
# 42 no es un número primo.

# %% [markdown]
# 8 - Vamos a comprender la distribución de edades de los pensionistas de una empresa de seguros. Escribe un programa que lea las edades de una cantidad no informada de clientes y muestre la distribución en los intervalos [0-25], [26-50], [51-75] y [76-100]. La entrada de datos se detendrá al ingresar un número negativo.

# %%
intervalos = {"0-25": 0, "26-50": 0, "51-75": 0, "76-100": 0}
while True:
      edad = int(input("Ingrese la edad del cliente (o un número negativo para finalizar): "))
      if edad < 0:
            break
      elif 0 <= edad <= 25:
            intervalos["0-25"] += 1
      elif 26 <= edad <= 50:
            intervalos["26-50"] += 1
      elif 51 <= edad <= 75:
            intervalos["51-75"] += 1
      elif 76 <= edad <= 100:
            intervalos["76-100"] += 1

print("Distribución de edades:")
for intervalo, cantidad in intervalos.items():
    print("{}: {}".format(intervalo, cantidad))
# Out:
# Distribución de edades:
# 0-25: 2
# 26-50: 4
# 51-75: 3
# 76-100: 3

# %% [markdown]
# 9 - En una elección para la gerencia de una empresa con 20 empleados, hay cuatro candidatos. Escribe un programa que calcule al ganador de la elección. La votación se realizó de la siguiente manera:
#
# Cada empleado votó por uno de los cuatro candidatos (representados por los números 1, 2, 3 y 4).
#
# También se contaron los votos nulos (representados por el número 5) y los votos en blanco (representados por el número 6).
#
# Al final de la votación, el programa debe mostrar el número total de votos para cada candidato, los votos nulos y los votos en blanco. Además, debe calcular y mostrar el porcentaje de votos nulos con respecto al total de votos y el porcentaje de votos en blanco con respecto al total de votos.

# %%
votos = {1: 0, 2: 0, 3: 0, 4: 0, "nulos": 0, "blancos": 0}
total_votos = 0
for i in range(20):
    voto = int(input("Empleado {}: Ingrese su voto (1-4 para candidatos, 5 para nulo, 6 para blanco): ".format(i + 1)))
    if voto in [1, 2, 3, 4]:
        votos[voto] += 1
    elif voto == 5:
        votos["nulos"] += 1
    elif voto == 6:
        votos["blancos"] += 1
    else:
        print("Voto inválido. No se contará este voto.")
    total_votos += 1
print("Resultados de la elección:")
for candidato in range(1, 5):
    print("Candidato {}: {} votos".format(candidato, votos[candidato]))
print("Votos nulos: {}".format(votos["nulos"]))
print("Votos en blanco: {}".format(votos["blancos"]))
if total_votos > 0:
    porcentaje_nulos = (votos["nulos"] / total_votos) * 100
    porcentaje_blancos = (votos["blancos"] / total_votos) * 100
    print("Porcentaje de votos nulos: {:.2f}%".format(porcentaje_nulos))
    print("Porcentaje de votos en blanco: {:.2f}%".format(porcentaje_blancos))
# Out:
# Voto inválido. No se contará este voto.
# Voto inválido. No se contará este voto.
# Voto inválido. No se contará este voto.
# Resultados de la elección:
# Candidato 1: 2 votos
# Candidato 2: 5 votos
# Candidato 3: 5 votos
# Candidato 4: 3 votos
# Votos nulos: 1
# Votos en blanco: 1
# Porcentaje de votos nulos: 5.00%
# Porcentaje de votos en blanco: 5.00%
